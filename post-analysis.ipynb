# %%
from abtem.measure import Measurement

# %%
import numpy as np
import glob

# %%
for file in glob.glob('*.hdf5'):
    name,_ = file.split('.')
    measurement = Measurement.read(file)
    measurement.save_as_image(name+'.png')

# %%
measurement.show()
# Out:
# (<AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>,
#  <matplotlib.image.AxesImage at 0x2ac806981790>)

# %%
measurement.show()
# Out:
# (<AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>,
#  <matplotlib.image.AxesImage at 0x2ac80692ffa0>)

# %%
measurement = Measurement.read('Zaxis100_interp_6_1200K_1.hdf5')

# %%
measurement.show()
# Out:
# (<AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>,
#  <matplotlib.image.AxesImage at 0x2ac806842ac0>)
